# %% [markdown]
# # Code to AI — Week 1, Day 3 · ASSIGNMENT 📝
# ### Due: **before the next class**
#
# **Submit:** push this notebook to GitHub and post the repo link in the WhatsApp group.
#
# **Topics:** `input()` · arithmetic · assignment · comparison · logical · membership operators
#
# **Rules:**
# - Only use what we've learned (no `if`/loops yet — Week 3 😉).
# - Use clean f-strings. Add a short comment on each task.
# - Run everything before submitting (**Restart & Run All**).

# %% [markdown]
# ## Task 1 — Greeting Machine (input) ⭐
# Ask the user for their **name** and **city**, then print one friendly f-string sentence using both.

# %%
# 👉 YOUR CODE HERE
name = input ("what is your name?")
city = input("in which city you live?")
print(f"{name}, It's so good to know you, and about {city} as it is an amazing place.")
# Out:
# Nabiha , It's so good to know you, and about Karachi as it is an amazing place.

# %% [markdown]
# ## Task 2 — Two-Number Stats (input + arithmetic) ⭐
# Ask for two numbers (cast to `float`). Print their **sum, difference, product, and division** (division rounded to 2 decimals).

# %%
# 👉 YOUR CODE HERE
a = float(input("First number: ")) # 5.5
b = float(input("Second number: "))  # 6.2
print(f"Sum = {a + b}")
# Out:
# Sum = 11.7

# %%
a = float(input("First number: ")) # 5.5
b = float(input("Second number: "))  # 6.2
print(f"difference = {a - b}")
# Out:
# difference = -0.7000000000000002

# %%
a = float(input("First number: ")) # 5.5
b = float(input("Second number: "))  # 6.2
print(f"Sum = {a / b}")
# Out:
# Sum = 0.8870967741935484

# %%
a = float(input("First number: ")) # 5.5
b = float(input("Second number: "))  # 6.2
print(f"Sum = {a * b}")
# Out:
# Sum = 34.1

# %% [markdown]
# ## Task 3 — Wallet Tracker (assignment operators) ⭐
# Start with `balance = 500`. Using `+=`, `-=`, `*=`:
# - add 200 (got pocket money)
# - subtract 150 (bought lunch)
# - print the final balance with an f-string.

# %%
balance = 500
# 👉 YOUR CODE HERE
balance = 500
print(f"Start: {balance}")
balance += 200      # add 200 balance = balance + 200
print(f"After += 200: {balance}")
# Out:
# Start: 500
# After += 200: 700

# %%
balance = 700
print(f"Start: {balance}")
balance -= 150      # subtract 150 balance = balance - 150
print(f"After -= 150: {balance}")
# Out:
# Start: 700
# After -= 150: 550

# %%
balance = 550
print= (f"The final amount that was saved by the user is {balance}")

# %% [markdown]
# ## Task 4 — True or False? (comparison + logical) ⭐⭐
# Without using `if`, **print** the result (`True`/`False`) of each:
# 1. Is 25 greater than 18?
# 2. Is 7 equal to 7 **and** 3 less than 1?
# 3. Is 10 not equal to 5 **or** 2 greater than 9?

# %%
# 👉 YOUR CODE HERE
print (25 > 18)
# Out:
# True

# %%
print(f"(7 == 7) and (3 < 1) -> {(7 == 7) and (3 < 1)}")
# Out:
# (7 == 7) and (3 < 1) -> False

# %%
print(f"(10 != 5) or (2 > 9) -> {(10 != 5) or (2 > 9)}")
# Out:
# (10 != 5) or (2 > 9) -> True

# %% [markdown]
# ## Task 5 — Name Detective (input + membership) ⭐⭐
# Ask the user for their full name, then **print** `True/False` for:
# 1. Is the letter `"a"` in the name?
# 2. Is `"z"` **not in** the name?

# %%
# 👉 YOUR CODE HERE
name = input("What is your name?")
print(f"Nice to meet you, {name}!")
# Out:
# Nice to meet you, Nabiha!

# %%
name = "Nabiha"
print(f"Is 'a' in name? -> {'a' in name}")
print(f"Is 'z' not in name? -> {'z' not in name}")
# Out:
# Is 'a' in name? -> True
# Is 'z' not in name? -> True

# %% [markdown]
# ---
# ### ✅ Before you submit
# - [ ] Every cell runs (Restart & Run All)
# - [ ] Each task has a comment
# - [ ] Pushed to GitHub + link posted in the group
#
# Awesome work! And don't forget the bigger **"About Me" Card** project. 💪🚀
